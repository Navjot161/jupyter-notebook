# %%
import tensorflow as tf

# %%
x = tf.constant(4, shape=(1,1), dtype=float)
print(x)
# Out:
# tf.Tensor([[4.]], shape=(1, 1), dtype=float32)

# %%
x = tf.ones([3,3])
x = tf.zeros([3,2])
x = tf.constant([[2,4,5],[3,6,8]])
x = tf.eye(3)
x = tf.random.normal([3,3], mean = 0, stddev=1)
x = tf.random.uniform([1,3], minval=0, maxval=1)
x = tf.range(start=1, limit=10, delta=2)
x = tf.cast(x, dtype=tf.float64)
print(x)
# Out:
# tf.Tensor([1. 3. 5. 7. 9.], shape=(5,), dtype=float64)

# %%
x = tf.constant([1,2,3])
y = tf.constant([9,8,7])

# z = tf.add(x, y)
# z = x + y

# z = tf.subtract(x, y)
# z = x-y

z = tf.divide(y, x)
z = x/y

z = x*y
z = tf.multiply(x, y)

z = tf.tensordot(x, y, axes=1)
z = x ** 5

x = tf.random.normal((4,3))
y = tf.random.normal((3,6))

z = tf.matmul(x, y)
print(z)
# Out:
# tf.Tensor(
# [[ 0.48089996  0.05696452 -0.15127814  1.1193283   1.2335867  -1.2930677 ]
#  [ 0.28026208 -4.5174193  -1.1408131   2.831956    0.63450176 -0.2744432 ]
#  [-0.28010306 -0.08302207  0.20491362 -0.8678209  -1.6195415   0.7505341 ]
#  [ 0.29811773  0.47971573  0.11584216  0.28147677  0.02371249 -0.85493547]], shape=(4, 6), dtype=float32)

# %%
x = tf.constant([0,2,3,1,5,4,6,7,8,8,8,9])
# print(x[:])
# print(x[2:])
# print(x[::2])
# print(x[::-1])

indices = tf.constant([0,4])
x_ind = tf.gather(x, indices)
print(x_ind)
# Out:
# tf.Tensor([0 5], shape=(2,), dtype=int32)

# %%
x = tf.constant([[2,3],
                [3,4],
                [4,5]])
print(x[:])
print(x[0:1])
# Out:
# tf.Tensor(
# [[2 3]
#  [3 4]
#  [4 5]], shape=(3, 2), dtype=int32)
# tf.Tensor([[2 3]], shape=(1, 2), dtype=int32)

# %%
x = tf.range(9)
x = tf.reshape(x,(3,3))
print(x)
x = tf.transpose(x, perm=[1,0])
print(x)
# Out:
# tf.Tensor(
# [[0 1 2]
#  [3 4 5]
#  [6 7 8]], shape=(3, 3), dtype=int32)
# tf.Tensor(
# [[0 3 6]
#  [1 4 7]
#  [2 5 8]], shape=(3, 3), dtype=int32)

# %%
a = tf.constant(5)
b = tf.constant([1,2,3])
c = tf.constant([[1,2],[3,4]])
d = tf.constant([[[1,2],[2,3]],[[5,6],[6,5]]])

print(a.shape, b.shape, c.shape, d.shape)
# Out:
# () (3,) (2, 2) (2, 2, 2)

# %%
c = tf.constant(10)
v = tf.Variable(5)

v.assign(7)
print(c)
print(v)
print(v.numpy())
# Out:
# tf.Tensor(10, shape=(), dtype=int32)
# 7
# 7

# %%
x = tf.Variable(5.0)

with tf.GradientTape() as tape:
  y = x**2 + 2*x + 1

  dy_dx = tape.gradient(y,x)
  print(dy_dx.numpy())
# Out:
# 12.0

# %%
x = tf.Variable(3.0)
y = tf.Variable(4.0)

with tf.GradientTape() as tape:
  z = x**2 + y**2
  gradients = tape.gradient(z, [x,y])
  print(gradients)
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=6.0>, <tf.Tensor: shape=(), dtype=float32, numpy=8.0>]

# %% [markdown]
# # New Section
